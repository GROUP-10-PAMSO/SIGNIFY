# %%
from matplotlib import pyplot as plt
import cv2

# %%
img1 = cv2.imread("test_image/test_1.jpg", cv2.IMREAD_GRAYSCALE)
img1 = cv2.resize(img1, (224, 224))

img2 = cv2.imread("test_image/test_2.jpg", cv2.IMREAD_GRAYSCALE)
img2 = cv2.resize(img2, (224, 224))

img3 = cv2.imread("test_image/test_3.jpg", cv2.IMREAD_GRAYSCALE)
img3 = cv2.resize(img3, (224, 224))

img4 = cv2.imread("test_image/test_4.jpg", cv2.IMREAD_GRAYSCALE)
img4 = cv2.resize(img4, (224, 224))

fig, ax = plt.subplots(1, 2, figsize=(10,10))
ax[0].imshow(img3, cmap=plt.get_cmap('gray'))
ax[1].imshow(img2, cmap=plt.get_cmap('gray'))
